# %%
from icrawler.builtin import GoogleImageCrawler
Google_Crawler = GoogleImageCrawler(parser_threads=2, downloader_threads=2, storage={'root_dir': 'data'})
Google_Crawler.crawl(keyword='flower', max_num=10000, date_min=None, date_max=None, min_size=(160,160), max_size=None)

# %%
from icrawler.builtin import GreedyImageCrawler
greedy_crawler = GreedyImageCrawler(parser_threads=2, downloader_threads=2,storage={'root_dir': 'girl'})
greedy_crawler.crawl(domains='www.***.com', max_num=10000, min_size=None, max_size=None)

# %%
from icrawler.builtin import BaiduImageCrawler
baidu_crawler = BaiduImageCrawler(storage={'root_dir': 'cat'})
baidu_crawler.crawl(keyword='猫',offset=0, max_num=999,min_size=None, max_size=None)
# Out:
# 2017-04-27 21:14:37,194 - INFO - icrawler.crawler - start crawling...
# 2017-04-27 21:14:37,197 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2017-04-27 21:14:37,199 - INFO - icrawler.crawler - starting 1 parser threads...
# 2017-04-27 21:14:37,201 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2017-04-27 21:14:37,387 - INFO - parser - parsing result page http://image.baidu.com/search/acjson?tn=resultjson_com&ipn=rj&word=猫&pn=0&rn=30
# 2017-04-27 21:14:37,666 - INFO - downloader - image #1	http://cdn.duitang.com/uploads/item/201409/10/20140910202229_tG5BN.jpeg
# 2017-04-27 21:14:38,159 - INFO - downloader - image #2	http://pic14.nipic.com/20110520/7449523_191806466000_2.jpg
# 2017-04-27 21:14:38,764 - INFO - downloader - image #3	http://www.yaochanglai.com/d/file/ziranmima/guaiyizhiwu/20170307/xxj2551dswdufrdm5.jpg
# 2017-04-27 21:14:38,904 - INFO - downloader - image #4	http://pic74.nipic.com/file/20150728/18138004_201107753000_2.jpg
# ...
